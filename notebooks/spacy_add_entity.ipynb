# %%
import spacy 

text = "the downside of single sample estimator is that it has high variance because it only uses one sample"

nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp(text)
doc
# Out:
# the downside of single sample estimator is that it has high variance because it only uses one sample

# %%
import pandas as pd 
def table_print(doc):
    data = []
    for token in doc:
        data.append([token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
                token.shape_, token.is_alpha, token.is_stop])
    return pd.DataFrame(data=data, columns=["TEXT", "LEMMA", "POS", "TAG", "DEP", "SHAPE", "ALPHA", "STOP"])
            

table_print(doc)
# Out:
#          TEXT      LEMMA    POS  TAG       DEP SHAPE  ALPHA   STOP
# 0         the        the    DET   DT       det   xxx   True   True
# 1    downside   downside   NOUN   NN     nsubj  xxxx   True  False
# 2          of         of    ADP   IN      prep    xx   True   True
# 3      single     single    ADJ   JJ      amod  xxxx   True  False
# 4      sample     sample   NOUN   NN  compound  xxxx   True  False
# 5   estimator  estimator   NOUN   NN      pobj  xxxx   True  False
# 6          is         be    AUX  VBZ      ROOT    xx   True   True
# 7        that       that  SCONJ   IN      mark  xxxx   True   True
# 8          it         it   PRON  PRP     nsubj    xx   True   True
# 9         has       have   VERB  VBZ     ccomp   xxx   True   True
# 10       high       high    ADJ   JJ      amod  xxxx   True  False
# 11   variance   variance   NOUN   NN      dobj  xxxx   True  False
# 12    because    because  SCONJ   IN      mark  xxxx   True   True
# ...

# %%
from spacy import displacy 

displacy.serve(doc, style="dep")
# Out:
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="252fbdf803f14cf28e86241b4d7e0047-0" class="displacy" width="3200" height="487.0" direction="ltr" style="max-width: none; height: 487.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="397.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# ...

# %%
doc[1].dep_
# Out:
# 'nsubj'

# %%
from spacy.matcher import DependencyMatcher

# %%
matcher = DependencyMatcher(nlp.vocab)
pattern = [
  {
    "RIGHT_ID": "anchor_founded",       # unique name
    "RIGHT_ATTRS": {"ORTH": "founded"}  # token pattern for "founded"
  }
]
matcher.add("PATTERN_NAME", [pattern])

# %%
ner = nlp.get_pipe('ner')
ner.add_label('single sample estimator')
# Out:
# 1

# %%
doc = nlp(text)

# %%
table_print(doc)
# Out:
#          TEXT      LEMMA    POS  TAG       DEP SHAPE  ALPHA   STOP
# 0         the        the    DET   DT       det   xxx   True   True
# 1    downside   downside   NOUN   NN     nsubj  xxxx   True  False
# 2          of         of    ADP   IN      prep    xx   True   True
# 3      single     single    ADJ   JJ      amod  xxxx   True  False
# 4      sample     sample   NOUN   NN  compound  xxxx   True  False
# 5   estimator  estimator   NOUN   NN      pobj  xxxx   True  False
# 6          is         be    AUX  VBZ      ROOT    xx   True   True
# 7        that       that  SCONJ   IN      mark  xxxx   True   True
# 8          it         it   PRON  PRP     nsubj    xx   True   True
# 9         has       have   VERB  VBZ     ccomp   xxx   True   True
# 10       high       high    ADJ   JJ      amod  xxxx   True  False
# 11   variance   variance   NOUN   NN      dobj  xxxx   True  False
# 12    because    because  SCONJ   IN      mark  xxxx   True   True
# ...
